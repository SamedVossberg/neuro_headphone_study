# %% [markdown]
# ### Data Analysis Headphone study
#
# In this notebook we will do some data analysis on data acquired at KD2Lab.\
# Let's start by importing the relevant tooling and loading the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
df = pd.read_csv('all_apps_wide-2025-03-06.csv')

# %%
df.head()
# Out:
#    participant.id_in_session participant.code  participant.label  \
# 0                          1         8gp06sxa                NaN
# 1                          2         sswre0ps                NaN
# 2                          3         ga0lmmg0                NaN
# 3                          4         uzvf1ov2                NaN
# 4                          5         ni3ulblj                NaN
#
#    participant._is_bot  participant._index_in_pages  \
# 0                    0                          370
# 1                    0                          371
# 2                    0                          371
# 3                    0                          370
# 4                    0                          370
#
#    participant._max_page_index participant._current_app_name  \
# 0                          371                  debriefing_3
# 1                          371                  debriefing_3
# 2                          371                  debriefing_3
# 3                          371                  debriefing_3
# 4                          371                  debriefing_3
#
#   participant._current_page_name participant.time_started_utc  \
# 0                     Debriefing   2025-03-06 14:50:25.669358
# 1                       ThankYou   2025-03-06 14:51:12.130240
# 2                       ThankYou   2025-03-06 14:51:30.677287
# 3                     Debriefing   2025-03-06 16:07:49.459604
# 4                     Debriefing   2025-03-06 16:07:49.473199
#
#    participant.visited  ...  headphones_finish_3.1.subsession.round_number  \
# 0                    1  ...                                              1
# 1                    1  ...                                              1
# 2                    1  ...                                              1
# 3                    1  ...                                              1
# 4                    1  ...                                              1
#
#    debriefing_3.1.player.id_in_group  debriefing_3.1.player.role  \
# 0                                  1                         NaN
# 1                                  2                         NaN
# 2                                  3                         NaN
# 3                                  4                         NaN
# 4                                  5                         NaN
#
#    debriefing_3.1.player.payoff  debriefing_3.1.player.mathsRating  \
# 0                           0.0                                NaN
# 1                           0.0                                7.0
# 2                           0.0                                3.0
# 3                           0.0                                NaN
# 4                           0.0                                NaN
#
#    debriefing_3.1.player.clickRating  debriefing_3.1.player.mathSkill  \
# 0                                NaN                              NaN
# 1                                7.0                              2.0
# 2                                2.0                              4.0
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#    debriefing_3.1.player.clickSkill  debriefing_3.1.group.id_in_subsession  \
# 0                               NaN                                      1
# 1                               3.0                                      1
# 2                               4.0                                      1
# 3                               NaN                                      1
# 4                               NaN                                      1
#
#    debriefing_3.1.subsession.round_number
# 0                                       1
# 1                                       1
# 2                                       1
# 3                                       1
# 4                                       1
#
# [5 rows x 1513 columns]

# %%
print(df.keys)
# Out:
# <bound method NDFrame.keys of    participant.id_in_session participant.code  participant.label  \
# 0                          1         8gp06sxa                NaN
# 1                          2         sswre0ps                NaN
# 2                          3         ga0lmmg0                NaN
# 3                          4         uzvf1ov2                NaN
# 4                          5         ni3ulblj                NaN
#
#    participant._is_bot  participant._index_in_pages  \
# 0                    0                          370
# 1                    0                          371
# 2                    0                          371
# 3                    0                          370
# 4                    0                          370
#
#    participant._max_page_index participant._current_app_name  \
# 0                          371                  debriefing_3
# 1                          371                  debriefing_3
# 2                          371                  debriefing_3
# 3                          371                  debriefing_3
# 4                          371                  debriefing_3
#
#   participant._current_page_name participant.time_started_utc  \
# 0                     Debriefing   2025-03-06 14:50:25.669358
# 1                       ThankYou   2025-03-06 14:51:12.130240
# 2                       ThankYou   2025-03-06 14:51:30.677287
# 3                     Debriefing   2025-03-06 16:07:49.459604
# 4                     Debriefing   2025-03-06 16:07:49.473199
#
#    participant.visited  ...  headphones_finish_3.1.subsession.round_number  \
# 0                    1  ...                                              1
# 1                    1  ...                                              1
# 2                    1  ...                                              1
# 3                    1  ...                                              1
# 4                    1  ...                                              1
#
#    debriefing_3.1.player.id_in_group  debriefing_3.1.player.role  \
# 0                                  1                         NaN
# 1                                  2                         NaN
# 2                                  3                         NaN
# 3                                  4                         NaN
# 4                                  5                         NaN
#
#    debriefing_3.1.player.payoff  debriefing_3.1.player.mathsRating  \
# 0                           0.0                                NaN
# 1                           0.0                                7.0
# 2                           0.0                                3.0
# 3                           0.0                                NaN
# 4                           0.0                                NaN
#
#    debriefing_3.1.player.clickRating  debriefing_3.1.player.mathSkill  \
# 0                                NaN                              NaN
# 1                                7.0                              2.0
# 2                                2.0                              4.0
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#    debriefing_3.1.player.clickSkill  debriefing_3.1.group.id_in_subsession  \
# 0                               NaN                                      1
# 1                               3.0                                      1
# 2                               4.0                                      1
# 3                               NaN                                      1
# 4                               NaN                                      1
#
#    debriefing_3.1.subsession.round_number
# 0                                       1
# 1                                       1
# 2                                       1
# 3                                       1
# 4                                       1
#
# [5 rows x 1513 columns]>

# %%
df.shape
# Out:
# (5, 1513)

# %%
#getting more data on the dataset
print(df.describe())
# Out:
#        participant.id_in_session  participant.label  participant._is_bot  \
# count                   5.000000                0.0                  5.0
# mean                    3.000000                NaN                  0.0
# std                     1.581139                NaN                  0.0
# min                     1.000000                NaN                  0.0
# 25%                     2.000000                NaN                  0.0
# 50%                     3.000000                NaN                  0.0
# 75%                     4.000000                NaN                  0.0
# max                     5.000000                NaN                  0.0
#
#        participant._index_in_pages  participant._max_page_index  \
# count                     5.000000                          5.0
# mean                    370.400000                        371.0
# std                       0.547723                          0.0
# min                     370.000000                        371.0
# 25%                     370.000000                        371.0
# 50%                     370.000000                        371.0
# 75%                     371.000000                        371.0
# max                     371.000000                        371.0
#
#        participant.visited  participant.mturk_worker_id  \
# count                  5.0                          0.0
# mean                   1.0                          NaN
# std                    0.0                          NaN
# min                    1.0                          NaN
# 25%                    1.0                          NaN
# 50%                    1.0                          NaN
# 75%                    1.0                          NaN
# max                    1.0                          NaN
#
#        participant.mturk_assignment_id  participant.payoff  \
# count                              0.0                 5.0
# mean                               NaN                 0.0
# std                                NaN                 0.0
# min                                NaN                 0.0
# 25%                                NaN                 0.0
# 50%                                NaN                 0.0
# 75%                                NaN                 0.0
# max                                NaN                 0.0
#
#        participant.puzzle_levels  ...  \
# count                        0.0  ...
# mean                         NaN  ...
# std                          NaN  ...
# min                          NaN  ...
# 25%                          NaN  ...
# 50%                          NaN  ...
# 75%                          NaN  ...
# max                          NaN  ...
#
#        headphones_finish_3.1.subsession.round_number  \
# count                                            5.0
# mean                                             1.0
# std                                              0.0
# min                                              1.0
# 25%                                              1.0
# 50%                                              1.0
# 75%                                              1.0
# max                                              1.0
#
#        debriefing_3.1.player.id_in_group  debriefing_3.1.player.role  \
# count                           5.000000                         0.0
# mean                            3.000000                         NaN
# std                             1.581139                         NaN
# min                             1.000000                         NaN
# 25%                             2.000000                         NaN
# 50%                             3.000000                         NaN
# 75%                             4.000000                         NaN
# max                             5.000000                         NaN
#
#        debriefing_3.1.player.payoff  debriefing_3.1.player.mathsRating  \
# count                           5.0                           2.000000
# mean                            0.0                           5.000000
# std                             0.0                           2.828427
# min                             0.0                           3.000000
# 25%                             0.0                           4.000000
# 50%                             0.0                           5.000000
# 75%                             0.0                           6.000000
# max                             0.0                           7.000000
#
#        debriefing_3.1.player.clickRating  debriefing_3.1.player.mathSkill  \
# count                           2.000000                         2.000000
# mean                            4.500000                         3.000000
# std                             3.535534                         1.414214
# min                             2.000000                         2.000000
# 25%                             3.250000                         2.500000
# 50%                             4.500000                         3.000000
# 75%                             5.750000                         3.500000
# max                             7.000000                         4.000000
#
#        debriefing_3.1.player.clickSkill  \
# count                          2.000000
# mean                           3.500000
# std                            0.707107
# min                            3.000000
# 25%                            3.250000
# 50%                            3.500000
# 75%                            3.750000
# max                            4.000000
#
#        debriefing_3.1.group.id_in_subsession  \
# count                                    5.0
# mean                                     1.0
# std                                      0.0
# min                                      1.0
# 25%                                      1.0
# 50%                                      1.0
# 75%                                      1.0
# max                                      1.0
#
#        debriefing_3.1.subsession.round_number
# count                                     5.0
# mean                                      1.0
# std                                       0.0
# min                                       1.0
# 25%                                       1.0
# 50%                                       1.0
# 75%                                       1.0
# max                                       1.0
#
# [8 rows x 1422 columns]

# %% [markdown]
# # Cleaning the data
# ### okay, now that we've seen that there is a lot of data for each of the 5 players.
#
# However, in the df.head we can see that player 2 and 3 seem to have more responses in some questions.\
# We will have to check if this is only in some questions or if we might have to focus only on these participants.\
# Let's start out by getting rid of all the columns filled with purely NaNs and see what those columns are.

# %%
df_all_nan = df.loc[:, df.isna().all()]
df_clean = df.loc[:, ~df.isna().all()]

# %%
print(df_all_nan.shape)
print(df_clean.shape)
# Out:
# (5, 721)
# (5, 792)

# %%
print(df_all_nan.keys())
# Out:
# Index(['participant.label', 'participant.mturk_worker_id',
#        'participant.mturk_assignment_id', 'participant.puzzle_levels',
#        'participant.puzzle_imgs', 'participant.puzzle_imgs_medium',
#        'participant.puzzle_imgs_easy', 'participant.puzzle_rounds',
#        'participant.puzzle_difficulty_selection', 'participant.math_levels',
#        ...
#        'headphones_finish_3.1.player.maia30',
#        'headphones_finish_3.1.player.maia31',
#        'headphones_finish_3.1.player.maia32',
#        'headphones_finish_3.1.player.maia33',
#        'headphones_finish_3.1.player.maia34',
#        'headphones_finish_3.1.player.maia35',
#        'headphones_finish_3.1.player.maia36',
#        'headphones_finish_3.1.player.maia37',
#        'headphones_finish_3.1.player.maia38c', 'debriefing_3.1.player.role'],
#       dtype='object', length=721)

# %%
df_clean.head()
# Out:
#    participant.id_in_session participant.code  participant._is_bot  \
# 0                          1         8gp06sxa                    0
# 1                          2         sswre0ps                    0
# 2                          3         ga0lmmg0                    0
# 3                          4         uzvf1ov2                    0
# 4                          5         ni3ulblj                    0
#
#    participant._index_in_pages  participant._max_page_index  \
# 0                          370                          371
# 1                          371                          371
# 2                          371                          371
# 3                          370                          371
# 4                          370                          371
#
#   participant._current_app_name participant._current_page_name  \
# 0                  debriefing_3                     Debriefing
# 1                  debriefing_3                       ThankYou
# 2                  debriefing_3                       ThankYou
# 3                  debriefing_3                     Debriefing
# 4                  debriefing_3                     Debriefing
#
#   participant.time_started_utc  participant.visited  participant.payoff  ...  \
# 0   2025-03-06 14:50:25.669358                    1                 0.0  ...
# 1   2025-03-06 14:51:12.130240                    1                 0.0  ...
# 2   2025-03-06 14:51:30.677287                    1                 0.0  ...
# 3   2025-03-06 16:07:49.459604                    1                 0.0  ...
# 4   2025-03-06 16:07:49.473199                    1                 0.0  ...
#
#   headphones_finish_3.1.group.id_in_subsession  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#   headphones_finish_3.1.subsession.round_number  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
#
#    debriefing_3.1.player.id_in_group debriefing_3.1.player.payoff  \
# 0                                  1                          0.0
# 1                                  2                          0.0
# 2                                  3                          0.0
# 3                                  4                          0.0
# 4                                  5                          0.0
#
#    debriefing_3.1.player.mathsRating  debriefing_3.1.player.clickRating  \
# 0                                NaN                                NaN
# 1                                7.0                                7.0
# 2                                3.0                                2.0
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    debriefing_3.1.player.mathSkill  debriefing_3.1.player.clickSkill  \
# 0                              NaN                               NaN
# 1                              2.0                               3.0
# 2                              4.0                               4.0
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   debriefing_3.1.group.id_in_subsession debriefing_3.1.subsession.round_number
# 0                                     1                                      1
# 1                                     1                                      1
# 2                                     1                                      1
# 3                                     1                                      1
# 4                                     1                                      1
#
# [5 rows x 792 columns]

# %% [markdown]
# ### Deleting the "Ghost Players"
#
# It seems like player 0,3 and 4 are not real players or are lacking too much information.\
# Therefore we will delete these empty rows

# %%
df_clean.drop(index= [0,3,4], inplace= True)
# Out:
# /var/folders/ml/fyq5x5t55wx4129dn03n32hm0000gn/T/ipykernel_87285/3581122541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(index= [0,3,4], inplace= True)

# %%
df_clean.head()
# Out:
#    participant.id_in_session participant.code  participant._is_bot  \
# 1                          2         sswre0ps                    0
# 2                          3         ga0lmmg0                    0
#
#    participant._index_in_pages  participant._max_page_index  \
# 1                          371                          371
# 2                          371                          371
#
#   participant._current_app_name participant._current_page_name  \
# 1                  debriefing_3                       ThankYou
# 2                  debriefing_3                       ThankYou
#
#   participant.time_started_utc  participant.visited  participant.payoff  ...  \
# 1   2025-03-06 14:51:12.130240                    1                 0.0  ...
# 2   2025-03-06 14:51:30.677287                    1                 0.0  ...
#
#   headphones_finish_3.1.group.id_in_subsession  \
# 1                                            1
# 2                                            1
#
#   headphones_finish_3.1.subsession.round_number  \
# 1                                             1
# 2                                             1
#
#    debriefing_3.1.player.id_in_group debriefing_3.1.player.payoff  \
# 1                                  2                          0.0
# 2                                  3                          0.0
#
#    debriefing_3.1.player.mathsRating  debriefing_3.1.player.clickRating  \
# 1                                7.0                                7.0
# 2                                3.0                                2.0
#
#    debriefing_3.1.player.mathSkill  debriefing_3.1.player.clickSkill  \
# 1                              2.0                               3.0
# 2                              4.0                               4.0
#
#   debriefing_3.1.group.id_in_subsession debriefing_3.1.subsession.round_number
# 1                                     1                                      1
# 2                                     1                                      1
#
# [2 rows x 792 columns]

# %% [markdown]
# ### Let's try to find the columns which contain data regarding the "whack-a-mole"-task
# In the csv file the math task is referrenced as "mathTask", while the whack-a-mole task is labelled "clickTask"

# %%
# creating a partial df with only the columns that contain the string 'clickTask' in the key/column name
df_clickTask = df_clean.loc[:, df_clean.columns.str.contains('clickTask')]
df_clickTask.head()
# Out:
#    clickTask_1.1.player.id_in_group  clickTask_1.1.player.payoff  \
# 1                                 2                          0.0
# 2                                 3                          0.0
#
#    clickTask_1.1.player.fss06  clickTask_1.1.player.fss08  \
# 1                           4                           6
# 2                           6                           7
#
#    clickTask_1.1.player.fss09  clickTask_1.1.player.tlx_single  \
# 1                           6                               17
# 2                           5                               17
#
#    clickTask_1.1.player.difficulty  clickTask_1.1.player.mr_mood  \
# 1                                2                           100
# 2                                3                            56
#
#    clickTask_1.1.player.mr_sleepy  clickTask_1.1.player.mr_motivy  ...  \
# 1                              99                             100  ...
# 2                              35                              42  ...
#
#   clickTask_3.8.player.mr_motivy  clickTask_3.8.player.mf_01  \
# 1                             54                           7
# 2                             16                           2
#
#    clickTask_3.8.player.mf_02  clickTask_3.8.player.mf_03  \
# 1                           7                           1
# 2                           2                           5
#
#    clickTask_3.8.player.mf_04  clickTask_3.8.player.headset_comfort  \
# 1                           1                                     2
# 2                           5                                     4
#
#                 clickTask_3.8.player.rest_actions_eo  \
# 1  ;onLoad;Thu Mar 06 2025 18:07:49 GMT+0100 (Mit...
# 2  ;onLoad;Thu Mar 06 2025 18:08:56 GMT+0100 (Mit...
#
#                 clickTask_3.8.player.rest_actions_ec  \
# 1  ;onLoad;Thu Mar 06 2025 18:07:17 GMT+0100 (Mit...
# 2  ;onLoad;Thu Mar 06 2025 18:08:23 GMT+0100 (Mit...
#
#    clickTask_3.8.group.id_in_subsession  clickTask_3.8.subsession.round_number
# 1                                     1                                      8
# 2                                     1                                      8
#
# [2 rows x 291 columns]

# %%
# getting all columns where "mathTask" is present in the key name
df_mathTask =  df_clean.loc[:, df_clean.columns.str.contains('mathTask')]
df_mathTask.head()
# Out:
#    mathTask_1.1.player.id_in_group  mathTask_1.1.player.payoff  \
# 1                                2                         0.0
# 2                                3                         0.0
#
#    mathTask_1.1.player.fss06  mathTask_1.1.player.fss08  \
# 1                          2                          6
# 2                          6                          6
#
#    mathTask_1.1.player.fss09  mathTask_1.1.player.tlx_single  \
# 1                          7                              14
# 2                          5                              17
#
#    mathTask_1.1.player.difficulty  mathTask_1.1.player.mr_mood  \
# 1                               2                           85
# 2                               4                           72
#
#    mathTask_1.1.player.mr_sleepy  mathTask_1.1.player.mr_motivy  ...  \
# 1                             82                             90  ...
# 2                             75                             73  ...
#
#   mathTask_3.8.player.mr_motivy  mathTask_3.8.player.mf_01  \
# 1                            50                          7
# 2                            13                          2
#
#    mathTask_3.8.player.mf_02  mathTask_3.8.player.mf_03  \
# 1                          7                          1
# 2                          2                          6
#
#    mathTask_3.8.player.mf_04  mathTask_3.8.player.headset_comfort  \
# 1                          1                                    2
# 2                          6                                    4
#
#                  mathTask_3.8.player.rest_actions_eo  \
# 1  ;onLoad;Thu Mar 06 2025 17:58:34 GMT+0100 (Mit...
# 2  ;onLoad;Thu Mar 06 2025 17:58:21 GMT+0100 (Mit...
#
#                  mathTask_3.8.player.rest_actions_ec  \
# 1  ;onLoad;Thu Mar 06 2025 17:58:01 GMT+0100 (Mit...
# 2  ;onLoad;Thu Mar 06 2025 17:57:49 GMT+0100 (Mit...
#
#    mathTask_3.8.group.id_in_subsession  mathTask_3.8.subsession.round_number
# 1                                    1                                     8
# 2                                    1                                     8
#
# [2 rows x 291 columns]

# %% [markdown]
# ### Now that we know that we know which data we have, let's check which data we are missing
# More specifically let's check if clickTask columns are missing data

# %%
# Let's get rid of the unnecessary lines:
df_all_nan.drop(index= [0,3,4], inplace= True)
# Out:
# /var/folders/ml/fyq5x5t55wx4129dn03n32hm0000gn/T/ipykernel_87285/2287721112.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_nan.drop(index= [0,3,4], inplace= True)

# %%
# checking which columns from the original df contain the string "clickTask" in the column name and simultaneously contain NaNs
nan_clickTask = df_all_nan.loc[:, df_all_nan.columns.str.contains("clickTask")]
nan_clickTask.head()
# Out:
#    clickTask_1.1.player.role  clickTask_1.1.player.mf_01  \
# 1                        NaN                         NaN
# 2                        NaN                         NaN
#
#    clickTask_1.1.player.mf_02  clickTask_1.1.player.mf_03  \
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#    clickTask_1.1.player.mf_04  clickTask_1.1.player.headset_comfort  \
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
#
#    clickTask_1.1.player.rest_actions_eo  clickTask_1.1.player.rest_actions_ec  \
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
#
#    clickTask_1.1.player.currRound  clickTask_1.2.player.role  ...  \
# 1                             NaN                        NaN  ...
# 2                             NaN                        NaN  ...
#
#    clickTask_3.7.player.rest_actions_ec  clickTask_3.7.player.click_actions  \
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
#
#    clickTask_3.7.player.currRound  clickTask_3.8.player.role  \
# 1                             NaN                        NaN
# 2                             NaN                        NaN
#
#    clickTask_3.8.player.fss06  clickTask_3.8.player.fss08  \
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#    clickTask_3.8.player.fss09  clickTask_3.8.player.difficulty  \
# 1                         NaN                              NaN
# 2                         NaN                              NaN
#
#    clickTask_3.8.player.click_actions  clickTask_3.8.player.currRound
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
#
# [2 rows x 237 columns]

# %%
# Now the same for the mathTask
nan_mathTask = df_all_nan.loc[:, df_all_nan.columns.str.contains('mathTask')]
nan_mathTask.head()
# Out:
#    mathTask_1.1.player.role  mathTask_1.1.player.mf_01  \
# 1                       NaN                        NaN
# 2                       NaN                        NaN
#
#    mathTask_1.1.player.mf_02  mathTask_1.1.player.mf_03  \
# 1                        NaN                        NaN
# 2                        NaN                        NaN
#
#    mathTask_1.1.player.mf_04  mathTask_1.1.player.headset_comfort  \
# 1                        NaN                                  NaN
# 2                        NaN                                  NaN
#
#    mathTask_1.1.player.rest_actions_eo  mathTask_1.1.player.rest_actions_ec  \
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
#
#    mathTask_1.1.player.currRound  mathTask_1.2.player.role  ...  \
# 1                            NaN                       NaN  ...
# 2                            NaN                       NaN  ...
#
#    mathTask_3.7.player.rest_actions_ec  mathTask_3.7.player.math_actions  \
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
#
#    mathTask_3.7.player.currRound  mathTask_3.8.player.role  \
# 1                            NaN                       NaN
# 2                            NaN                       NaN
#
#    mathTask_3.8.player.fss06  mathTask_3.8.player.fss08  \
# 1                        NaN                        NaN
# 2                        NaN                        NaN
#
#    mathTask_3.8.player.fss09  mathTask_3.8.player.difficulty  \
# 1                        NaN                             NaN
# 2                        NaN                             NaN
#
#    mathTask_3.8.player.math_actions  mathTask_3.8.player.currRound
# 1                               NaN                            NaN
# 2                               NaN                            NaN
#
# [2 rows x 237 columns]

# %% [markdown]
# ##### Looks like we've quite some data missing
# However it seems like the NaN values are always the same.
# Let's check this for the reaction task.

# %%
missing_atts_click = dict(Counter(col.split('.player.')[1] for col in nan_clickTask.columns))

print(missing_atts_click)
# Out:
# {'role': 24, 'mf_01': 21, 'mf_02': 21, 'mf_03': 21, 'mf_04': 21, 'headset_comfort': 21, 'rest_actions_eo': 21, 'rest_actions_ec': 21, 'currRound': 24, 'fss06': 6, 'fss08': 6, 'fss09': 6, 'tlx_single': 3, 'difficulty': 6, 'mr_mood': 3, 'mr_sleepy': 3, 'mr_motivy': 3, 'click_actions': 6}

# %%
missing_atts_math = dict(Counter(col.split('.player.')[1] for col in  nan_mathTask.columns))

print(missing_atts_math)
# Out:
# {'role': 24, 'mf_01': 21, 'mf_02': 21, 'mf_03': 21, 'mf_04': 21, 'headset_comfort': 21, 'rest_actions_eo': 21, 'rest_actions_ec': 21, 'currRound': 24, 'fss06': 6, 'fss08': 6, 'fss09': 6, 'tlx_single': 3, 'difficulty': 6, 'mr_mood': 3, 'mr_sleepy': 3, 'mr_motivy': 3, 'math_actions': 6}
